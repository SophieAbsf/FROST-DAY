# %% [markdown]
# # Data quality
#
# Notebook de controle qualite pour inspecter les donnees quotidiennes recuperees via DPClimatologie.

# %%
import pandas as pd

# Charger un export CSV depuis l'interface Streamlit pour verifier les valeurs manquantes.
# df = pd.read_csv('../frost_days_export.csv')
# df.isna().mean()
